# %%
import pandas as pd
import numpy as np

# %%
data  = pd.read_csv('student_marks.csv')

# %%
data.head()
# Out:
#        Name Gender         DOB  Maths  Physics  Chemistry  English  Biology  \
# 0      John      M  05-04-1988     55       45         56       87       21
# 1    Suresh      M  04-05-1987     75       96         78       64       90
# 2    Ramesh      M  25-05-1989     25       54         89       76       95
# 3   Jessica      F  12-08-1990     78       96         86       63       54
# 4  Jennifer      F  02-09-1989     58       96         78       46       96
#
#    Economics  History  Civics
# 0         52       89      65
# 1         61       58       2
# 2         87       56      74
# 3         89       75      45
# 4         77       83      53

# %%
data[(data['Gender']=='M') & (data["Name"]=='Mukesh')]
# Out:
#      Name Gender         DOB  Maths  Physics  Chemistry  English  Biology  \
# 9  Mukesh      M  02-09-1989     96       46         77       83       58
#
#    Economics  History  Civics
# 9         83       46      77

# %%
data.loc[~((data["Gender"]=="M")& (data['Name']=="Mukesh"))]
# Out:
#        Name Gender         DOB  Maths  Physics  Chemistry  English  Biology  \
# 0      John      M  05-04-1988     55       45         56       87       21
# 1    Suresh      M  04-05-1987     75       96         78       64       90
# 2    Ramesh      M  25-05-1989     25       54         89       76       95
# 3   Jessica      F  12-08-1990     78       96         86       63       54
# 4  Jennifer      F  02-09-1989     58       96         78       46       96
# 5      Annu      F  05-04-1988     45       87         52       89       55
# 6     pooja      F  04-05-1987     55       64         61       58       75
# 7    Ritesh      M  25-05-1989     54       76         87       56       25
# 8     Farha      F  12-08-1990     55       63         89       75       78
#
#    Economics  History  Civics
# 0         52       89      65
# 1         61       58       2
# 2         87       56      74
# 3         89       75      45
# 4         77       83      53
# ...

# %%
data["Name"].replace('John','Rohn')
# Out:
# 0        Rohn
# 1      Suresh
# 2      Ramesh
# 3     Jessica
# 4    Jennifer
# 5        Annu
# 6       pooja
# 7      Ritesh
# 8       Farha
# 9      Mukesh
# Name: Name, dtype: object

# %%
data["Total"] = data['Biology']+data['Chemistry']+data['Physics']+data['Maths']+data['English']+data["History"]+data['Civics']+data['Economics']
data
# Out:
#        Name Gender         DOB  Maths  Physics  Chemistry  English  Biology  \
# 0      John      M  05-04-1988     55       45         56       87       21
# 1    Suresh      M  04-05-1987     75       96         78       64       90
# 2    Ramesh      M  25-05-1989     25       54         89       76       95
# 3   Jessica      F  12-08-1990     78       96         86       63       54
# 4  Jennifer      F  02-09-1989     58       96         78       46       96
# 5      Annu      F  05-04-1988     45       87         52       89       55
# 6     pooja      F  04-05-1987     55       64         61       58       75
# 7    Ritesh      M  25-05-1989     54       76         87       56       25
# 8     Farha      F  12-08-1990     55       63         89       75       78
# 9    Mukesh      M  02-09-1989     96       46         77       83       58
#
#    Economics  History  Civics  Total
# 0         52       89      65    470
# 1         61       58       2    524
# ...

# %%
data["Perc"] = ((data['Biology']+data['Chemistry']+data['Physics']+data['Maths']+data['English']+data["History"]+data['Civics']+data['Economics'])*100)/700
data
# Out:
#        Name Gender         DOB  Maths  Physics  Chemistry  English  Biology  \
# 0      John      M  05-04-1988     55       45         56       87       21
# 1    Suresh      M  04-05-1987     75       96         78       64       90
# 2    Ramesh      M  25-05-1989     25       54         89       76       95
# 3   Jessica      F  12-08-1990     78       96         86       63       54
# 4  Jennifer      F  02-09-1989     58       96         78       46       96
# 5      Annu      F  05-04-1988     45       87         52       89       55
# 6     pooja      F  04-05-1987     55       64         61       58       75
# 7    Ritesh      M  25-05-1989     54       76         87       56       25
# 8     Farha      F  12-08-1990     55       63         89       75       78
# 9    Mukesh      M  02-09-1989     96       46         77       83       58
#
#    Economics  History  Civics  Total    Average grade       Perc
# 0         52       89      65    470  67.142857     c  67.142857
# ...

# %%
def getgrade(perc):
    perc = 0
    if perc >= 70:
        return "A"
    elif perc >= 60 and perc<40:
        return "B"
    else:
        return "c"
data['grade'] = data['Gender'].apply(getgrade)

# %%
data.drop('grade',axis=1,inplace=True)

# %%
data
# Out:
#        Name Gender         DOB  Maths  Physics  Chemistry  English  Biology  \
# 0      John      M  05-04-1988     55       45         56       87       21
# 1    Suresh      M  04-05-1987     75       96         78       64       90
# 2    Ramesh      M  25-05-1989     25       54         89       76       95
# 3   Jessica      F  12-08-1990     78       96         86       63       54
# 4  Jennifer      F  02-09-1989     58       96         78       46       96
# 5      Annu      F  05-04-1988     45       87         52       89       55
# 6     pooja      F  04-05-1987     55       64         61       58       75
# 7    Ritesh      M  25-05-1989     54       76         87       56       25
# 8     Farha      F  12-08-1990     55       63         89       75       78
# 9    Mukesh      M  02-09-1989     96       46         77       83       58
#
#    Economics  History  Civics  Total    Average       Perc grade
# 0         52       89      65    470  67.142857  67.142857     c
# ...

# %%
data['Maths'] = data['Maths'].astype(int)

# %%
grpmaths = data['Maths'].min()
grpmaths
# Out:
# 25

# %%
grpmaths = data['Maths'].max()
grpmaths
# Out:
# 96

# %%
grpmaths = data['Maths'].mean()
grpmaths
# Out:
# 59.6

# %%
grpmaths = data['Maths'].mode()
grpmaths
# Out:
# 0    55
# Name: Maths, dtype: int32

# %%
df1 = pd.DataFrame({
   'A': [1, 2, 3, 4],
   'B': [5, 6, 7, 8]})

# %%
df2 = pd.DataFrame({
   'A': [9, 10, 11, 12],
   'B': [13, 14, 15, 16]})

# %%
result = pd.concat([df1, df2])
result
# Out:
#     A   B
# 0   1   5
# 1   2   6
# 2   3   7
# 3   4   8
# 0   9  13
# 1  10  14
# 2  11  15
# 3  12  16

# %%
data1 = {'empid':list(range(1,6)),'empdept':['HR','Admin','Sales','Crm',"IT"]}
df2 = pd.DataFrame(data1)


df2
# Out:
#    empid empdept
# 0      1      HR
# 1      2   Admin
# 2      3   Sales
# 3      4     Crm
# 4      5      IT

# %%
data2 = {'deptid':list(range(101,106)),'count':[20,50,60,30,10]}
df3 = pd.DataFrame(data2)
df3
# Out:
#    deptid  count
# 0     101     20
# 1     102     50
# 2     103     60
# 3     104     30
# 4     105     10

# %%
pd.concat([df2,df3])
# Out:
#    empid empdept  deptid  count
# 0    1.0      HR     NaN    NaN
# 1    2.0   Admin     NaN    NaN
# 2    3.0   Sales     NaN    NaN
# 3    4.0     Crm     NaN    NaN
# 4    5.0      IT     NaN    NaN
# 0    NaN     NaN   101.0   20.0
# 1    NaN     NaN   102.0   50.0
# 2    NaN     NaN   103.0   60.0
# 3    NaN     NaN   104.0   30.0
# 4    NaN     NaN   105.0   10.0

# %%
pd.concat([df2,df3],ignore_index=True)
# Out:
#    empid empdept  deptid  count
# 0    1.0      HR     NaN    NaN
# 1    2.0   Admin     NaN    NaN
# 2    3.0   Sales     NaN    NaN
# 3    4.0     Crm     NaN    NaN
# 4    5.0      IT     NaN    NaN
# 5    NaN     NaN   101.0   20.0
# 6    NaN     NaN   102.0   50.0
# 7    NaN     NaN   103.0   60.0
# 8    NaN     NaN   104.0   30.0
# 9    NaN     NaN   105.0   10.0

# %%
df = pd.DataFrame([{'a':'xyz',
                    'b':'lmn',
                    }])
df.dtypes
# Out:
# a    object
# b    object
# dtype: object

# %%
df.T
# Out:
#      0
# a  xyz
# b  lmn
