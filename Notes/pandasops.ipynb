# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('student_marks.csv')

# %%
df
# Out:
#        Name Gender         DOB  Maths  Physics  Chemistry  English  Biology  \
# 0      John      M  05-04-1988     55       45         56       87       21
# 1    Suresh      M  04-05-1987     75       96         78       64       90
# 2    Ramesh      M  25-05-1989     25       54         89       76       95
# 3   Jessica      F  12-08-1990     78       96         86       63       54
# 4  Jennifer      F  02-09-1989     58       96         78       46       96
# 5      Annu      F  05-04-1988     45       87         52       89       55
# 6     pooja      F  04-05-1987     55       64         61       58       75
# 7    Ritesh      M  25-05-1989     54       76         87       56       25
# 8     Farha      F  12-08-1990     55       63         89       75       78
# 9    Mukesh      M  02-09-1989     96       46         77       83       58
#
#    Economics  History  Civics
# 0         52       89      65
# 1         61       58       2
# 2         87       56      74
# ...

# %%
df['Name']
# Out:
# 0        John
# 1      Suresh
# 2      Ramesh
# 3     Jessica
# 4    Jennifer
# 5        Annu
# 6       pooja
# 7      Ritesh
# 8       Farha
# 9      Mukesh
# Name: Name, dtype: object

# %%
df[['Name','Gender']]
# Out:
#        Name Gender
# 0      John      M
# 1    Suresh      M
# 2    Ramesh      M
# 3   Jessica      F
# 4  Jennifer      F
# 5      Annu      F
# 6     pooja      F
# 7    Ritesh      M
# 8     Farha      F
# 9    Mukesh      M

# %%
# iloc and loc
df.loc[2:5]
# Out:
#        Name Gender         DOB  Maths  Physics  Chemistry  English  Biology  \
# 2    Ramesh      M  25-05-1989     25       54         89       76       95
# 3   Jessica      F  12-08-1990     78       96         86       63       54
# 4  Jennifer      F  02-09-1989     58       96         78       46       96
# 5      Annu      F  05-04-1988     45       87         52       89       55
#
#    Economics  History  Civics
# 2         87       56      74
# 3         89       75      45
# 4         77       83      53
# 5         89       87      52

# %%
df.loc[2:5,2:3]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [9], in <cell line: 1>()
# ----> 1 df.loc[2:5,2:3]
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:961, in _LocationIndexer.__getitem__(self, key)
#     959     if self._is_scalar_access(key):
#     960         return self.obj._get_value(*key, takeable=self._takeable)
# --> 961     return self._getitem_tuple(key)
#     962 else:
#     963     # we by definition only have the 0th axis
#     964     axis = self.axis or 0
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:1149, in _LocIndexer._getitem_tuple(self, tup)
#    1146 if self._multi_take_opportunity(tup):
#    1147     return self._multi_take(tup)
# -> 1149 return self._getitem_tuple_same_dim(tup)
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:827, in _LocationIndexer._getitem_tuple_same_dim(self, tup)
# ...

# %%
df.loc[2:5,'Name']
# Out:
# 2      Ramesh
# 3     Jessica
# 4    Jennifer
# 5        Annu
# Name: Name, dtype: object

# %%
df.loc[2:5,['Name','Gender']]
# Out:
#        Name Gender
# 2    Ramesh      M
# 3   Jessica      F
# 4  Jennifer      F
# 5      Annu      F

# %%
names=df.loc[2:5,['Name','Gender']]

# %%
names
# Out:
#        Name Gender
# 2    Ramesh      M
# 3   Jessica      F
# 4  Jennifer      F
# 5      Annu      F

# %%
df.loc[:,'Physics':'Biology':2]
# Out:
#    Physics  English
# 0       45       87
# 1       96       64
# 2       54       76
# 3       96       63
# 4       96       46
# 5       87       89
# 6       64       58
# 7       76       56
# 8       63       75
# 9       46       83

# %%
df.loc[df['Gender']=='M']
# Out:
#      Name Gender         DOB  Maths  Physics  Chemistry  English  Biology  \
# 0    John      M  05-04-1988     55       45         56       87       21
# 1  Suresh      M  04-05-1987     75       96         78       64       90
# 2  Ramesh      M  25-05-1989     25       54         89       76       95
# 7  Ritesh      M  25-05-1989     54       76         87       56       25
# 9  Mukesh      M  02-09-1989     96       46         77       83       58
#
#    Economics  History  Civics
# 0         52       89      65
# 1         61       58       2
# 2         87       56      74
# 7         56       76      87
# 9         83       46      77

# %%
df.loc[df['Gender']=='M','Name']
# Out:
# 0      John
# 1    Suresh
# 2    Ramesh
# 7    Ritesh
# 9    Mukesh
# Name: Name, dtype: object

# %%
males=df.loc[df['Gender']=='M','Name']

# %%
males
# Out:
# 0      John
# 1    Suresh
# 2    Ramesh
# 7    Ritesh
# 9    Mukesh
# Name: Name, dtype: object

# %%
df.loc[df['Gender']=='M',['Gender','Name']]
# Out:
#   Gender    Name
# 0      M    John
# 1      M  Suresh
# 2      M  Ramesh
# 7      M  Ritesh
# 9      M  Mukesh

# %%
df.loc[~(df['Gender']=='M')]
# Out:
#        Name Gender         DOB  Maths  Physics  Chemistry  English  Biology  \
# 3   Jessica      F  12-08-1990     78       96         86       63       54
# 4  Jennifer      F  02-09-1989     58       96         78       46       96
# 5      Annu      F  05-04-1988     45       87         52       89       55
# 6     pooja      F  04-05-1987     55       64         61       58       75
# 8     Farha      F  12-08-1990     55       63         89       75       78
#
#    Economics  History  Civics
# 3         89       75      45
# 4         77       83      53
# 5         89       87      52
# 6         58       64      61
# 8         75       63      89

# %%
#iloc
df.iloc[2:5]
# Out:
#        Name Gender         DOB  Maths  Physics  Chemistry  English  Biology  \
# 2    Ramesh      M  25-05-1989     25       54         89       76       95
# 3   Jessica      F  12-08-1990     78       96         86       63       54
# 4  Jennifer      F  02-09-1989     58       96         78       46       96
#
#    Economics  History  Civics
# 2         87       56      74
# 3         89       75      45
# 4         77       83      53

# %%
df.iloc[2:5,0]
# Out:
# 2      Ramesh
# 3     Jessica
# 4    Jennifer
# Name: Name, dtype: object

# %%
df.iloc[:,2:5]
# Out:
#           DOB  Maths  Physics
# 0  05-04-1988     55       45
# 1  04-05-1987     75       96
# 2  25-05-1989     25       54
# 3  12-08-1990     78       96
# 4  02-09-1989     58       96
# 5  05-04-1988     45       87
# 6  04-05-1987     55       64
# 7  25-05-1989     54       76
# 8  12-08-1990     55       63
# 9  02-09-1989     96       46

# %%
df.iloc[:,[0,7,10]]
# Out:
#        Name  Biology  Civics
# 0      John       21      65
# 1    Suresh       90       2
# 2    Ramesh       95      74
# 3   Jessica       54      45
# 4  Jennifer       96      53
# 5      Annu       55      52
# 6     pooja       75      61
# 7    Ritesh       25      87
# 8     Farha       78      89
# 9    Mukesh       58      77

# %%
cl=df.iloc[:,[0,7,10]]

# %%
cl
# Out:
#        Name  Biology  Civics
# 0      John       21      65
# 1    Suresh       90       2
# 2    Ramesh       95      74
# 3   Jessica       54      45
# 4  Jennifer       96      53
# 5      Annu       55      52
# 6     pooja       75      61
# 7    Ritesh       25      87
# 8     Farha       78      89
# 9    Mukesh       58      77

# %%
type(cl)
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#        Name Gender         DOB  Maths  Physics  Chemistry  English  Biology  \
# 0      John      M  05-04-1988     55       45         56       87       21
# 1    Suresh      M  04-05-1987     75       96         78       64       90
# 2    Ramesh      M  25-05-1989     25       54         89       76       95
# 3   Jessica      F  12-08-1990     78       96         86       63       54
# 4  Jennifer      F  02-09-1989     58       96         78       46       96
# 5      Annu      F  05-04-1988     45       87         52       89       55
# 6     pooja      F  04-05-1987     55       64         61       58       75
# 7    Ritesh      M  25-05-1989     54       76         87       56       25
# 8     Farha      F  12-08-1990     55       63         89       75       78
# 9    Mukesh      M  02-09-1989     96       46         77       83       58
#
#    Economics  History  Civics  sci_total
# 0         52       89      65        177
# 1         61       58       2        339
# ...

# %%
df['sci_total']=df['Maths']+df['Physics']+df['Chemistry']+df['Biology']

# %%
df['sci_total']
# Out:
# 0    177
# 1    339
# 2    263
# 3    314
# 4    328
# 5    239
# 6    255
# 7    242
# 8    285
# 9    277
# Name: sci_total, dtype: int64

# %%
#concat
data1={'Name':['Jay','Raj','Kumar'],
      'Age':[20,25,23],
      'dept':['Hr','Sales','Account']}
df1=pd.DataFrame(data1)

# %%
data2={'deptid':list(range(0,3)),
      'count':list(range(10,40,10))}
df2=pd.DataFrame(data2,dtype=int)

# %%
newdf=pd.concat([df1,df2])

# %%
newdf
# Out:
#     Name   Age     dept  deptid  count
# 0    Jay  20.0       Hr     NaN    NaN
# 1    Raj  25.0    Sales     NaN    NaN
# 2  Kumar  23.0  Account     NaN    NaN
# 0    NaN   NaN      NaN     0.0   10.0
# 1    NaN   NaN      NaN     1.0   20.0
# 2    NaN   NaN      NaN     2.0   30.0

# %%
newdf=pd.concat([df1,df2],ignore_index=True)
newdf
# Out:
#     Name   Age     dept  deptid  count
# 0    Jay  20.0       Hr     NaN    NaN
# 1    Raj  25.0    Sales     NaN    NaN
# 2  Kumar  23.0  Account     NaN    NaN
# 3    NaN   NaN      NaN     0.0   10.0
# 4    NaN   NaN      NaN     1.0   20.0
# 5    NaN   NaN      NaN     2.0   30.0

# %%
newdf.isna().sum()
# Out:
# Name      3
# Age       3
# dept      3
# deptid    3
# count     3
# dtype: int64

# %%
newdf.notna().sum()
# Out:
# Name      3
# Age       3
# dept      3
# deptid    3
# count     3
# dtype: int64

# %%
newdf['Name'].replace(np.NaN,'abc')
# Out:
# 0      Jay
# 1      Raj
# 2    Kumar
# 3      abc
# 4      abc
# 5      abc
# Name: Name, dtype: object

# %%
newdf
# Out:
#     Name   Age     dept  deptid  count
# 0    Jay  20.0       Hr     NaN    NaN
# 1    Raj  25.0    Sales     NaN    NaN
# 2  Kumar  23.0  Account     NaN    NaN
# 3    NaN   NaN      NaN     0.0   10.0
# 4    NaN   NaN      NaN     1.0   20.0
# 5    NaN   NaN      NaN     2.0   30.0

# %%
newdf['Name'].replace(np.NaN,'abc',inplace=True)

# %%
newdf
# Out:
#     Name   Age     dept  deptid  count
# 0    Jay  20.0       Hr     NaN    NaN
# 1    Raj  25.0    Sales     NaN    NaN
# 2  Kumar  23.0  Account     NaN    NaN
# 3    abc   NaN      NaN     0.0   10.0
# 4    abc   NaN      NaN     1.0   20.0
# 5    abc   NaN      NaN     2.0   30.0

# %%
dmean=np.mean(newdf['deptid'])

# %%
dmean
# Out:
# 1.0

# %%
newdf['deptid'].replace(np.NaN,dmean,inplace=True)

# %%
newdf
# Out:
#     Name   Age     dept  deptid  count
# 0    Jay  20.0       Hr     1.0    NaN
# 1    Raj  25.0    Sales     1.0    NaN
# 2  Kumar  23.0  Account     1.0    NaN
# 3    abc   NaN      NaN     0.0   10.0
# 4    abc   NaN      NaN     1.0   20.0
# 5    abc   NaN      NaN     2.0   30.0

# %%
df
# Out:
#        Name Gender         DOB  Maths  Physics  Chemistry  English  Biology  \
# 0      John      M  05-04-1988     55       45         56       87       21
# 1    Suresh      M  04-05-1987     75       96         78       64       90
# 2    Ramesh      M  25-05-1989     25       54         89       76       95
# 3   Jessica      F  12-08-1990     78       96         86       63       54
# 4  Jennifer      F  02-09-1989     58       96         78       46       96
# 5      Annu      F  05-04-1988     45       87         52       89       55
# 6     pooja      F  04-05-1987     55       64         61       58       75
# 7    Ritesh      M  25-05-1989     54       76         87       56       25
# 8     Farha      F  12-08-1990     55       63         89       75       78
# 9    Mukesh      M  02-09-1989     96       46         77       83       58
#
#    Economics  History  Civics  sci_total
# 0         52       89      65        177
# 1         61       58       2        339
# ...

# %%
import datetime
dt=datetime.datetime.now()
import warnings
warnings.filterwarnings("ignore")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 15 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Name       10 non-null     object
#  1   Gender     10 non-null     object
#  2   DOB        10 non-null     datetime64[ns]
#  3   Maths      10 non-null     int64
#  4   Physics    10 non-null     int64
#  5   Chemistry  10 non-null     int64
#  6   English    10 non-null     int64
#  7   Biology    10 non-null     int64
#  8   Economics  10 non-null     int64
#  9   History    10 non-null     int64
#  10  Civics     10 non-null     int64
#  11  sci_total  10 non-null     int64
#  12  year       10 non-null     int64
#  13  Month      10 non-null     int64
#  14  day        10 non-null     int64
# dtypes: datetime64[ns](1), int64(12), object(2)
# memory usage: 1.3+ KB

# %%
df['DOB']=pd.to_datetime(df['DOB'])

# %%
df['year']=df['DOB'].dt.year

# %%
df['year']
# Out:
# 0    1988
# 1    1987
# 2    1989
# 3    1990
# 4    1989
# 5    1988
# 6    1987
# 7    1989
# 8    1990
# 9    1989
# Name: year, dtype: int64

# %%
df
# Out:
#        Name Gender        DOB  Maths  Physics  Chemistry  English  Biology  \
# 0      John      M 1988-05-04     55       45         56       87       21
# 1    Suresh      M 1987-04-05     75       96         78       64       90
# 2    Ramesh      M 1989-05-25     25       54         89       76       95
# 3   Jessica      F 1990-12-08     78       96         86       63       54
# 4  Jennifer      F 1989-02-09     58       96         78       46       96
# 5      Annu      F 1988-05-04     45       87         52       89       55
# 6     pooja      F 1987-04-05     55       64         61       58       75
# 7    Ritesh      M 1989-05-25     54       76         87       56       25
# 8     Farha      F 1990-12-08     55       63         89       75       78
# 9    Mukesh      M 1989-02-09     96       46         77       83       58
#
#    Economics  History  Civics  sci_total  year
# 0         52       89      65        177  1988
# 1         61       58       2        339  1987
# ...

# %%
df['Month']=df['DOB'].dt.month
df
# Out:
#        Name Gender        DOB  Maths  Physics  Chemistry  English  Biology  \
# 0      John      M 1988-05-04     55       45         56       87       21
# 1    Suresh      M 1987-04-05     75       96         78       64       90
# 2    Ramesh      M 1989-05-25     25       54         89       76       95
# 3   Jessica      F 1990-12-08     78       96         86       63       54
# 4  Jennifer      F 1989-02-09     58       96         78       46       96
# 5      Annu      F 1988-05-04     45       87         52       89       55
# 6     pooja      F 1987-04-05     55       64         61       58       75
# 7    Ritesh      M 1989-05-25     54       76         87       56       25
# 8     Farha      F 1990-12-08     55       63         89       75       78
# 9    Mukesh      M 1989-02-09     96       46         77       83       58
#
#    Economics  History  Civics  sci_total  year  Month
# 0         52       89      65        177  1988      5
# ...

# %%
df['day']=df['DOB'].dt.day

# %%
df
# Out:
#        Name Gender        DOB  Maths  Physics  Chemistry  English  Biology  \
# 0      John      M 1988-05-04     55       45         56       87       21
# 1    Suresh      M 1987-04-05     75       96         78       64       90
# 2    Ramesh      M 1989-05-25     25       54         89       76       95
# 3   Jessica      F 1990-12-08     78       96         86       63       54
# 4  Jennifer      F 1989-02-09     58       96         78       46       96
# 5      Annu      F 1988-05-04     45       87         52       89       55
# 6     pooja      F 1987-04-05     55       64         61       58       75
# 7    Ritesh      M 1989-05-25     54       76         87       56       25
# 8     Farha      F 1990-12-08     55       63         89       75       78
# 9    Mukesh      M 1989-02-09     96       46         77       83       58
#
#    Economics  History  Civics  sci_total  year  Month  day
# 0         52       89      65        177  1988      5    4
# ...

# %%
total=df[~(df['sci_total']>=300) & (df['Gender']=='M')]
total
# Out:
#      Name Gender        DOB  Maths  Physics  Chemistry  English  Biology  \
# 0    John      M 1988-05-04     55       45         56       87       21
# 2  Ramesh      M 1989-05-25     25       54         89       76       95
# 7  Ritesh      M 1989-05-25     54       76         87       56       25
# 9  Mukesh      M 1989-02-09     96       46         77       83       58
#
#    Economics  History  Civics  sci_total  year  Month  day
# 0         52       89      65        177  1988      5    4
# 2         87       56      74        263  1989      5   25
# 7         56       76      87        242  1989      5   25
# 9         83       46      77        277  1989      2    9

# %%
def getgrade(marks):

    if(marks>=300):
        return "A+"
    elif (marks>=200 and marks<300):
        return 'B'
    else:
        return 'C'

df['Grade']=df['sci_total'].apply(getgrade)

# %%
df
# Out:
#        Name Gender         DOB  Maths  Physics  Chemistry  English  Biology  \
# 0      John      M  05-04-1988     55       45         56       87       21
# 1    Suresh      M  04-05-1987     75       96         78       64       90
# 2    Ramesh      M  25-05-1989     25       54         89       76       95
# 3   Jessica      F  12-08-1990     78       96         86       63       54
# 4  Jennifer      F  02-09-1989     58       96         78       46       96
# 5      Annu      F  05-04-1988     45       87         52       89       55
# 6     pooja      F  04-05-1987     55       64         61       58       75
# 7    Ritesh      M  25-05-1989     54       76         87       56       25
# 8     Farha      F  12-08-1990     55       63         89       75       78
# 9    Mukesh      M  02-09-1989     96       46         77       83       58
#
#    Economics  History  Civics  sci_total Grade
# 0         52       89      65        177     C
# ...

# %%
df.groupby('Grade')

# %%
df.groupby('Grade').count()
# Out:
#        Name  Gender  DOB  Maths  Physics  Chemistry  English  Biology  \
# Grade
# A+        3       3    3      3        3          3        3        3
# B         6       6    6      6        6          6        6        6
# C         1       1    1      1        1          1        1        1
#
#        Economics  History  Civics  sci_total
# Grade
# A+             3        3       3          3
# B              6        6       6          6
# C              1        1       1          1

# %%
df.groupby('Grade')['Maths'].agg(['mean','max','min','count'])
# Out:
#             mean  max  min  count
# Grade
# A+     70.333333   78   58      3
# B      55.000000   96   25      6
# C      55.000000   55   55      1

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
xdata=[3,6,7,8]
ydata=[1,2,3,4]

plt.plot(xdata,ydata)
plt.show()

# %%
xdata=[3,6,7,8]
ydata=[1,2,3,4]


plt.plot(xdata,ydata)
plt.xlabel("X-axis", color='r')
plt.ylabel("Y-axis",color='g')
plt.title("Example of line chart" ,fontstyle='italic',fontweight='20')
plt.show()

# %%
xdata=[3,6,7,8]
ydata=[1,2,3,4]


plt.plot(xdata,ydata,'-.',color='#FF0000')
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("Example of line chart")
plt.show()

# %%
xdata=[3,6,7,8]
ydata=[1,2,3,4]
xdata1=[5,6,9,7]
ydata1=[2,3,4,5]

plt.plot(xdata,ydata,'-.',color='#FF0000',linewidth=5)
plt.plot(xdata1,ydata1,'-.',color='g')
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("Example of line chart")
plt.show()

# %%
xdata=[3,6,7,8]
ydata=[1,2,3,4]

plt.bar(xdata,ydata,width=0.8,color='g')
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("Example of line chart")
plt.show()

# %%
xdata=[3,6,7,8]
ydata=[1,2,3,4]
mycolors=['red','hotpink','blue','g']
plt.bar(xdata,ydata,width=0.8,color=mycolors)
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("Example of line chart")
plt.show()

# %%
xdata=[3,6,7,8]
ydata=[1,2,3,4]
mycolors=['red','pink','blue','g']
plt.bar(xdata,ydata,width=0.8,color=mycolors,alpha=1)
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("Example of line chart")
plt.show()
