# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
page = requests.get("https://www.flipkart.com/mobile-phones-store?fm=neo%2Fmerchandising&iid=M_90df203e-1cd0-4e96-9c3d-ec35777c2530_1_372UD5BXDFYS_MC.ZRQ4DKH28K8J&otracker=hp_rich_navigation_2_1.navigationCard.RICH_NAVIGATION_Mobiles_ZRQ4DKH28K8J&otracker1=hp_rich_navigation_PINNED_neo%2Fmerchandising_NA_NAV_EXPANDABLE_navigationCard_cc_2_L0_view-all&cid=ZRQ4DKH28K8J")

# %%
page.content
# Out:
# b'<!doctype html><html lang="en"><head><link href="https://rukminim2.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.09b0e9.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.e82689.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><link rel="shortcut icon" href="https:///www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57" href="/apple-touch-icon-57x57.png"/><link rel="apple-touch-icon" 
# ...

# %%
soup = BeautifulSoup(page.content)
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
product_name = soup.find_all('a',class_="s1Q9rs")
product_name
# Out:
# [<a class="s1Q9rs" href="/realme-12-5g-twilight-purple-128-gb/p/itm33bab7c9fcc8e?pid=MOBGYAFKR424BCHQ&amp;lid=LSTMOBGYAFKR424BCHQI66RZS&amp;marketplace=FLIPKART&amp;fm=neo%2Fmerchandising&amp;iid=M_52d80ffb-1a7c-4302-80b5-e81ee6304426_26_VKQAC8JJSL3T_MC.MOBGYAFKR424BCHQ&amp;ppt=None&amp;ppn=None&amp;ssid=gh5qyks4sw0000001712053222838&amp;otracker=clp_pmu_v2_Realme%2Bsmartphones_1_26.productCard.PMU_V2_realme%2B12%2B5G%2B%2528Twilight%2BPurple%252C%2B128%2BGB%2529_mobile-phones-store_MOBGYAFKR424BCHQ_neo%2Fmerchandising_0&amp;otracker1=clp_pmu_v2_PINNED_neo%2Fmerchandising_Realme%2Bsmartphones_LIST_productCard_cc_1_NA_view-all&amp;cid=MOBGYAFKR424BCHQ" rel="noopener noreferrer" target="_blank" title="realme 12 5G (Twilight Purple, 128 GB)">realme 12 5G (Twilight Purple, 128 GB)</a>,
# ...

# %%
product_list = []
for i in product_name:
    product_list.append(i.text)
product_list
# Out:
# ['realme 12 5G (Twilight Purple, 128 GB)',
#  'realme 11 5G (Glory Gold, 256 GB)',
#  'realme 12 Pro+ 5G (Submarine Blue, 128 GB)',
#  'realme 12 5G (Woodland Green, 128 GB)',
#  'realme C51 (Mint Green, 64 GB)',
#  'realme C53 (Champion Gold, 128 GB)',
#  'POCO C51 - Locked with Airtel Prepaid (Royal Blue, 64 GB)',
#  'POCO M6 Pro 5G (Forest Green, 128 GB)',
#  'POCO C55 (Power Black, 64 GB)',
#  'POCO M6 5G (Polaris Green, 256 GB)',
#  'POCO C61 (Diamond Dust Black, 64 GB)',
#  'POCO X6 Pro 5G (Spectre Black, 256 GB)',
#  'SAMSUNG Galaxy F15 5G (Ash Black, 128 GB)',
#  'SAMSUNG Galaxy F15 5G (Jazzy Green, 128 GB)',
#  'SAMSUNG Galaxy S23 Ultra 5G (Green, 256 GB)',
#  'SAMSUNG Galaxy F14 5G (GOAT Green, 128 GB)',
#  'SAMSUNG Galaxy F14 5G (OMG Black, 128 GB)',
#  'SAMSUNG Galaxy F54 5G (Stardust Silver, 256 GB)',
#  'vivo T2x 5G (Marine Blue, 128 GB)',
#  'vivo T2x 5G (Sunstone Orange, 128 GB)',
#  'vivo T2 Pro 5G (Dune Gold, 256 GB)',
#  'vivo V30 Pro 5G (Andaman Blue, 256 GB)',
# ...

# %%
product_price = soup.find_all(class_="_30jeq3")
product_price
# Out:
# [<div class="_30jeq3">₹16,999</div>,
#  <div class="_30jeq3">₹17,999</div>,
#  <div class="_30jeq3">₹29,999</div>,
#  <div class="_30jeq3">₹16,999</div>,
#  <div class="_30jeq3">₹7,999</div>,
#  <div class="_30jeq3">₹10,499</div>,
#  <div class="_30jeq3">₹4,999</div>,
#  <div class="_30jeq3">₹9,999</div>,
#  <div class="_30jeq3">₹9,499</div>,
#  <div class="_30jeq3">₹11,999</div>,
#  <div class="_30jeq3">₹6,999</div>,
#  <div class="_30jeq3">₹25,999</div>,
#  <div class="_30jeq3">₹12,999</div>,
#  <div class="_30jeq3">₹12,999</div>,
#  <div class="_30jeq3">₹99,999</div>,
#  <div class="_30jeq3">₹13,490</div>,
#  <div class="_30jeq3">₹13,490</div>,
#  <div class="_30jeq3">₹24,999</div>,
#  <div class="_30jeq3">₹12,999</div>,
#  <div class="_30jeq3">₹12,999</div>,
#  <div class="_30jeq3">₹24,999</div>,
#  <div class="_30jeq3">₹41,999</div>,
#  <div class="_30jeq3">₹32,999</div>,
#  <div class="_30jeq3">₹15,999</div>,
#  <div class="_30jeq3">₹52,999</div>,
# ...

# %%
prize_list = []
for i in product_price:
    prize_list.append(i.text)
prize_list
# Out:
# ['₹16,999',
#  '₹17,999',
#  '₹29,999',
#  '₹16,999',
#  '₹7,999',
#  '₹10,499',
#  '₹4,999',
#  '₹9,999',
#  '₹9,499',
#  '₹11,999',
#  '₹6,999',
#  '₹25,999',
#  '₹12,999',
#  '₹12,999',
#  '₹99,999',
#  '₹13,490',
#  '₹13,490',
#  '₹24,999',
#  '₹12,999',
#  '₹12,999',
#  '₹24,999',
#  '₹41,999',
#  '₹32,999',
#  '₹15,999',
#  '₹52,999',
#  '₹72,999',
#  '₹58,999',
#  '₹42,999',
#  '₹58,999',
#  '₹58,999']

# %%
discount_list = []
for i in discount_applied:
    discount_list.append(i.text)
discount_list
# Out:
# ['15% off',
#  '21% off',
#  '14% off',
#  '15% off',
#  '27% off',
#  '25% off',
#  '50% off',
#  '37% off',
#  '20% off',
#  '25% off',
#  '22% off',
#  '16% off',
#  '18% off',
#  '18% off',
#  '33% off',
#  '27% off',
#  '27% off',
#  '30% off',
#  '31% off',
#  '31% off',
#  '10% off',
#  '10% off',
#  '33% off',
#  '11% off',
#  '8% off',
#  '15% off',
#  '13% off',
#  '15% off',
#  '15% off']

# %%
customer_purchased = soup.find_all(class_="_2_R_DZ")
customer_purchased
# Out:
# [<span class="_2_R_DZ">(2,309)</span>,
#  <span class="_2_R_DZ">(63,565)</span>,
#  <span class="_2_R_DZ">(7,283)</span>,
#  <span class="_2_R_DZ">(2,309)</span>,
#  <span class="_2_R_DZ">(76,299)</span>,
#  <span class="_2_R_DZ">(1,13,645)</span>,
#  <span class="_2_R_DZ">(2,02,527)</span>,
#  <span class="_2_R_DZ">(61,533)</span>,
#  <span class="_2_R_DZ">(1,16,247)</span>,
#  <span class="_2_R_DZ">(3,252)</span>,
#  <span class="_2_R_DZ">(40)</span>,
#  <span class="_2_R_DZ">(4,430)</span>,
#  <span class="_2_R_DZ">(2,218)</span>,
#  <span class="_2_R_DZ">(2,218)</span>,
#  <span class="_2_R_DZ">(3,190)</span>,
#  <span class="_2_R_DZ">(95,587)</span>,
#  <span class="_2_R_DZ">(95,587)</span>,
#  <span class="_2_R_DZ">(24,524)</span>,
#  <span class="_2_R_DZ">(3,82,784)</span>,
#  <span class="_2_R_DZ">(3,82,784)</span>,
#  <span class="_2_R_DZ">(80,934)</span>,
#  <span class="_2_R_DZ">(1,278)</span>,
#  <span class="_2_R_DZ">(8,586)</span>,
# ...

# %%
customer_purchased_list = []
for i in customer_purchased:
    customer_purchased_list.append(i.text)
customer_purchased_list
# Out:
# ['(2,309)',
#  '(63,565)',
#  '(7,283)',
#  '(2,309)',
#  '(76,299)',
#  '(1,13,645)',
#  '(2,02,527)',
#  '(61,533)',
#  '(1,16,247)',
#  '(3,252)',
#  '(40)',
#  '(4,430)',
#  '(2,218)',
#  '(2,218)',
#  '(3,190)',
#  '(95,587)',
#  '(95,587)',
#  '(24,524)',
#  '(3,82,784)',
#  '(3,82,784)',
#  '(80,934)',
#  '(1,278)',
#  '(8,586)',
#  '(1,04,450)',
#  '(2,79,230)',
#  '(21,259)',
#  '(2,86,377)',
#  '(2,08,639)',
#  '(2,86,377)',
#  '(2,86,377)']

# %%
Amazon = pd.DataFrame({})
Amazon['Mobile_Name'] = product_list
Amazon['Prize'] = prize_list
Amazon['Customer_Purchased'] = customer_purchased

# %%
Amazon
# Out:
#                                           Mobile_Name Prize_After_Discount  \
# 0              realme 12 5G (Twilight Purple, 128 GB)              ₹16,999
# 1                   realme 11 5G (Glory Gold, 256 GB)              ₹17,999
# 2          realme 12 Pro+ 5G (Submarine Blue, 128 GB)              ₹29,999
# 3               realme 12 5G (Woodland Green, 128 GB)              ₹16,999
# 4                      realme C51 (Mint Green, 64 GB)               ₹7,999
# 5                  realme C53 (Champion Gold, 128 GB)              ₹10,499
# 6   POCO C51 - Locked with Airtel Prepaid (Royal B...               ₹4,999
# 7               POCO M6 Pro 5G (Forest Green, 128 GB)               ₹9,999
# 8                       POCO C55 (Power Black, 64 GB)               ₹9,499
# 9                  POCO M6 5G (Polaris Green, 256 GB)              ₹11,999
# 10               POCO C61 (Diamond Dust Black, 64 GB)               ₹6,999
# ...

# %%
Amazon.to_csv("Amazon_Products.csv")
