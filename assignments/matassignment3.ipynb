# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
a = np.arange(0, 100)
b = a * 2
c = a ** 2

# %%
fig = plt.figure()
axs1 = fig.add_axes([0, 0, 1, 1])
axs2 = fig.add_axes([0.2, 0.5, 0.4, 0.4])
axs1.plot(a,c, color='blue')
axs2.plot(a,b, color='red')
axs1.set_xlabel('A')
axs1.set_ylabel('C')
axs1.set_title('Main Plot')
axs2.set_xlabel('X')
axs2.set_ylabel('Y')
axs2.set_title('Inset Plot')
axs2.set_xlim(20, 40)
axs2.set_ylim(40, 80)
plt.show()
