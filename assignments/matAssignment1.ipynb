# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
a = np.arange(0, 100)
b = a * 2
c = a ** 2

# %%
sns.set()  
plt.plot(a, b)
plt.xlabel('X Label')
plt.ylabel('Y Label')
plt.title('Plot of a versus b')
plt.show()
