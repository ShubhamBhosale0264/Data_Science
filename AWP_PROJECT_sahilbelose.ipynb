# %%
#import the necessary labraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
#Load the data
df=pd.read_csv(r'C:\Users\cyrus\Downloads\IPL 2022 Batters.csv')
df
# Out:
#                   Player  Mat  Inns  NO  Runs    HS    Avg   BF      SR  100  \
# 0            Jos Buttler   17    17   2   863   116  57.53  579  149.05    4
# 1              K L Rahul   15    15   3   616  103*  51.33  455  135.38    2
# 2        Quinton De Kock   15    15   1   508  140*  36.29  341  148.97    1
# 3          Hardik Pandya   15    15   4   487   87*  44.27  371  131.26    0
# 4           Shubman Gill   16    16   2   483    96   34.5  365  132.32    0
# ..                   ...  ...   ...  ..   ...   ...    ...  ...     ...  ...
# 157     Fazalhaq Farooqi    3     1   1     2    2*      -    8   25.00    0
# 158   Jagadeesha Suchith    5     2   0     2     2      1    8   25.00    0
# 159          Tim Southee    9     5   1     2    1*    0.5   12   16.66    0
# 160  Nathan Coulter-Nile    1     1   1     1    1*      -    2   50.00    0
# 161        Anrich Nortje    6     1   1     1    1*      -    6   16.66    0
#
#      50  4s
# 0     4  83
# 1     4  45
# ...

# %%
#replace some column names
df.rename({'Mat':'Matches','Inns':'Innings','HS':'High_Score','Avg':'Average'},axis=1,inplace=True)
df
# Out:
#                   Player  Matches  Innings  NO  Runs High_Score Average   BF  \
# 0            Jos Buttler       17       17   2   863        116   57.53  579
# 1              K L Rahul       15       15   3   616       103*   51.33  455
# 2        Quinton De Kock       15       15   1   508       140*   36.29  341
# 3          Hardik Pandya       15       15   4   487        87*   44.27  371
# 4           Shubman Gill       16       16   2   483         96    34.5  365
# ..                   ...      ...      ...  ..   ...        ...     ...  ...
# 157     Fazalhaq Farooqi        3        1   1     2         2*       -    8
# 158   Jagadeesha Suchith        5        2   0     2          2       1    8
# 159          Tim Southee        9        5   1     2         1*     0.5   12
# 160  Nathan Coulter-Nile        1        1   1     1         1*       -    2
# 161        Anrich Nortje        6        1   1     1         1*       -    6
#
#          SR  100  50  4s
# ...

# %%
#display the head of the dataset
a=df.head()
a
# Out:
#             Player  Matches  Innings  NO  Runs High_Score Average   BF  \
# 0      Jos Buttler       17       17   2   863        116   57.53  579
# 1        K L Rahul       15       15   3   616       103*   51.33  455
# 2  Quinton De Kock       15       15   1   508       140*   36.29  341
# 3    Hardik Pandya       15       15   4   487        87*   44.27  371
# 4     Shubman Gill       16       16   2   483         96    34.5  365
#
#        SR  100  50  4s
# 0  149.05    4   4  83
# 1  135.38    2   4  45
# 2  148.97    1   3  47
# 3  131.26    0   4  49
# 4  132.32    0   4  51

# %%
#display bottom five rows
df.tail()
# Out:
#                   Player  Matches  Innings  NO  Runs High_Score Average  BF  \
# 157     Fazalhaq Farooqi        3        1   1     2         2*       -   8
# 158   Jagadeesha Suchith        5        2   0     2          2       1   8
# 159          Tim Southee        9        5   1     2         1*     0.5  12
# 160  Nathan Coulter-Nile        1        1   1     1         1*       -   2
# 161        Anrich Nortje        6        1   1     1         1*       -   6
#
#         SR  100  50  4s
# 157  25.00    0   0   0
# 158  25.00    0   0   0
# 159  16.66    0   0   0
# 160  50.00    0   0   0
# 161  16.66    0   0   0

# %%
#display basic info of dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 162 entries, 0 to 161
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Player      162 non-null    object
#  1   Matches     162 non-null    int64
#  2   Innings     162 non-null    int64
#  3   NO          162 non-null    int64
#  4   Runs        162 non-null    int64
#  5   High_Score  162 non-null    object
#  6   Average     162 non-null    object
#  7   BF          162 non-null    int64
#  8   SR          162 non-null    float64
#  9   100         162 non-null    int64
#  10  50          162 non-null    int64
#  11  4s          162 non-null    int64
# dtypes: float64(1), int64(8), object(3)
# memory usage: 15.3+ KB

# %%
#analytical summary of dataset
df.describe()
# Out:
#           Matches     Innings          NO        Runs          BF          SR  \
# count  162.000000  162.000000  162.000000  162.000000  162.000000  162.000000
# mean     9.160494    7.141975    1.586420  142.296296  106.061728  120.406235
# std      5.047493    4.816982    1.819989  161.252161  114.571234   45.192799
# min      1.000000    1.000000    0.000000    1.000000    1.000000   16.660000
# 25%      5.000000    3.000000    0.000000   14.500000   14.000000   94.082500
# 50%      9.500000    7.000000    1.000000   65.000000   47.500000  123.620000
# 75%     14.000000   11.000000    2.000000  241.500000  176.500000  144.247500
# max     17.000000   17.000000   10.000000  863.000000  579.000000  400.000000
#
#               100          50          4s
# count  162.000000  162.000000  162.000000
# mean     0.049383    0.679012   12.450617
# std      0.366322    1.172428   15.314529
# min      0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    1.000000
# ...

# %%
#find the null values
df.isnull().sum()
# Out:
# Player        0
# Matches       0
# Innings       0
# NO            0
# Runs          0
# High_Score    0
# Average       0
# BF            0
# SR            0
# 100           0
# 50            0
# 4s            0
# dtype: int64

# %%
df=df['Matches']==3
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [5], in <cell line: 1>()
# ----> 1 df=df['Matches']==3
#       2 df
#
# NameError: name 'df' is not defined

# %%
#replacing using nan function
df['Innings']=df['Innings'].replace(2,np.nan)
df
# Out:
#                   Player  Matches  Innings  NO  Runs High_Score Average   BF  \
# 0            Jos Buttler       17     17.0   2   863        116   57.53  579
# 1              K L Rahul       15     15.0   3   616       103*   51.33  455
# 2        Quinton De Kock       15     15.0   1   508       140*   36.29  341
# 3          Hardik Pandya       15     15.0   4   487        87*   44.27  371
# 4           Shubman Gill       16     16.0   2   483         96    34.5  365
# ..                   ...      ...      ...  ..   ...        ...     ...  ...
# 157     Fazalhaq Farooqi        3      1.0   1     2         2*       -    8
# 158   Jagadeesha Suchith        5      NaN   0     2          2       1    8
# 159          Tim Southee        9      5.0   1     2         1*     0.5   12
# 160  Nathan Coulter-Nile        1      1.0   1     1         1*       -    2
# 161        Anrich Nortje        6      1.0   1     1         1*       -    6
#
#          SR  100  50  4s
# ...

# %%
#finding mean of column '100'
m=df['100'].mean()
m
# Out:
# 0.04938271604938271

# %%
df['Innings']=df['Innings'].replace(np.nan,m)
df
# Out:
#                   Player  Matches    Innings  NO  Runs High_Score Average  \
# 0            Jos Buttler       17  17.000000   2   863        116   57.53
# 1              K L Rahul       15  15.000000   3   616       103*   51.33
# 2        Quinton De Kock       15  15.000000   1   508       140*   36.29
# 3          Hardik Pandya       15  15.000000   4   487        87*   44.27
# 4           Shubman Gill       16  16.000000   2   483         96    34.5
# ..                   ...      ...        ...  ..   ...        ...     ...
# 157     Fazalhaq Farooqi        3   1.000000   1     2         2*       -
# 158   Jagadeesha Suchith        5   0.049383   0     2          2       1
# 159          Tim Southee        9   5.000000   1     2         1*     0.5
# 160  Nathan Coulter-Nile        1   1.000000   1     1         1*       -
# 161        Anrich Nortje        6   1.000000   1     1         1*       -
#
#       BF      SR  100  50  4s
# 0    579  149.05    4   4  83
# ...

# %%
sns.distplot(df['Matches'])
# Out:
# <AxesSubplot:xlabel='Matches', ylabel='Density'>

# %%
#plotting a histogram for "runs" columns
sns.histplot(df['Runs'])
# Out:
# <AxesSubplot:xlabel='Runs', ylabel='Count'>

# %%
#segregating quantitative and qualitative data
df_cat=df.select_dtypes('object')
df_num=df.select_dtypes(['int','float'])
df_cat
# Out:
#                   Player High_Score Average
# 0            Jos Buttler        116   57.53
# 1              K L Rahul       103*   51.33
# 2        Quinton De Kock       140*   36.29
# 3          Hardik Pandya        87*   44.27
# 4           Shubman Gill         96    34.5
# ..                   ...        ...     ...
# 157     Fazalhaq Farooqi         2*       -
# 158   Jagadeesha Suchith          2       1
# 159          Tim Southee         1*     0.5
# 160  Nathan Coulter-Nile         1*       -
# 161        Anrich Nortje         1*       -
#
# [162 rows x 3 columns]

# %%
#plotting a barplot for the column 'Mat'
sns.barplot(df['Matches'],df['Runs'])
# Out:
# <AxesSubplot:xlabel='Matches', ylabel='Runs'>

# %%
#quantitative data
df_num
# Out:
#      Matches    Innings  NO  Runs   BF      SR  100  50  4s
# 0         17  17.000000   2   863  579  149.05    4   4  83
# 1         15  15.000000   3   616  455  135.38    2   4  45
# 2         15  15.000000   1   508  341  148.97    1   3  47
# 3         15  15.000000   4   487  371  131.26    0   4  49
# 4         16  16.000000   2   483  365  132.32    0   4  51
# ..       ...        ...  ..   ...  ...     ...  ...  ..  ..
# 157        3   1.000000   1     2    8   25.00    0   0   0
# 158        5   0.049383   0     2    8   25.00    0   0   0
# 159        9   5.000000   1     2   12   16.66    0   0   0
# 160        1   1.000000   1     1    2   50.00    0   0   0
# 161        6   1.000000   1     1    6   16.66    0   0   0
#
# [162 rows x 9 columns]

# %%
#using for loop to show distplot of all columns one by one
for i in df_num:
    sns.distplot(df[i])
    plt.show()

# %%
#plotting one qualitative and one quantitative column using box plot
sns.boxplot(df['Innings'],df['Runs'])
# Out:
# <AxesSubplot:xlabel='Innings', ylabel='Runs'>

# %%
#Match played by greater than 15
df[df['Matches']>15]
# Out:
#                   Player  Matches    Innings  NO  Runs High_Score Average  \
# 0            Jos Buttler       17  17.000000   2   863        116   57.53
# 4           Shubman Gill       16  16.000000   2   483         96    34.5
# 5           David Miller       16  16.000000   9   481        94*   68.71
# 6         Faf Du Plessis       16  16.000000   1   468         96    31.2
# 8           Sanju Samson       17  17.000000   1   458         55   28.63
# 18      Devdutt Padikkal       17  17.000000   0   376         54   22.12
# 21           Virat Kohli       16  16.000000   1   341         73   22.73
# 25        Dinesh Karthik       16  16.000000  10   330        66*      55
# 44         Shahbaz Ahmed       16  11.000000   3   219         45   27.38
# 45         Rahul Tewatia       16  12.000000   5   217        43*      31
# 49   Ravichandran Ashwin       17  12.000000   5   191         50   27.29
# 51           Riyan Parag       17  14.000000   3   183        56*   16.64
# ...

# %%
#plotting one qualitative and one quantitative column using box plot
sns.boxplot(df['Matches'],df['50'])
# Out:
# <AxesSubplot:xlabel='Matches', ylabel='50'>

# %%
#show data where innings is 17 and runs are greater than 500
df[(df['Innings']==17)&(df['Runs']>500)]
# Out:
#         Player  Matches  Innings  NO  Runs High_Score Average   BF      SR  \
# 0  Jos Buttler       17     17.0   2   863        116   57.53  579  149.05
#
#    100  50  4s
# 0    4   4  83

# %%
#using for loop showing boxpplots one by one
for i in df_num:
    sns.boxplot(df[i],df['Matches'])
    plt.show()

# %%
#Scatter plots are the graphs that present the relationship between two variables in a data-set
sns.scatterplot(df['Matches'],df['Runs'])
# Out:
# <AxesSubplot:xlabel='Matches', ylabel='Runs'>

# %%
#This function provides access to several different axes-level functions that show the relationship between two variables with
#semantic mappings of subsets
sns.relplot(df['Matches'],df['Runs'],kind='line')

# %%
#A count plot can be thought of as a histogram across a categorical, instead of quantitative, variable
sns.countplot(df['Matches'],data=df)
# Out:
# <AxesSubplot:xlabel='Matches', ylabel='count'>

# %%
#Python Seaborn module contains various functions to plot the data and depict the data variations.
#The kde parameter is set to True to enable the Kernel Density Plot along with the distplot.
sns.distplot(df['Innings'],kde=True)
# Out:
# <AxesSubplot:xlabel='Innings', ylabel='Density'>

# %%
#Python Seaborn module contains various functions to plot the data and depict the data variations.
sns.distplot(df['Innings'],kde=True,hist=False)
# Out:
# <AxesSubplot:xlabel='Innings', ylabel='Density'>

# %%
#Seaborn jointplot provides a convenient interface to the class of joint grid by using several types of points.
sns.jointplot(df['Matches'],df['Runs'])

# %%
sns.jointplot(df['Matches'],df['Runs'],data=df,kind='kde')

# %%
#To plot multiple pairwise bivariate distributions in a dataset, you can use the pairplot() function
sns.pairplot(df)

# %%
#To plot multiple pairwise bivariate distributions in a dataset, you can use the pairplot() function
sns.violinplot(df['Matches'],df['Runs'])
# Out:
# <AxesSubplot:xlabel='Matches', ylabel='Runs'>

# %%
# stripplot is used to draw a scatter plot based on the category.
sns.stripplot(df['Matches'],df['Runs'])
# Out:
# <AxesSubplot:xlabel='Matches', ylabel='Runs'>

# %%
#jitter can be used to provide displacements along the horizontal axis
sns.stripplot(df['Matches'],df['Runs'],data=df,jitter=True,dodge=True,hue='100')
# Out:
# <AxesSubplot:xlabel='Matches', ylabel='Runs'>

# %%
#This method is used to plot data and a linear regression model fit
sns.regplot(df['Matches'],df['SR'],data=df)
# Out:
# <AxesSubplot:xlabel='Matches', ylabel='SR'>

# %%
#an heatmap is used to find the relations between variables
s=df.corr()
sns.heatmap(s)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>
