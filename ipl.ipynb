# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
import seaborn as sns

# %%
ipl = pd.read_csv('matches.csv')

# %%
ipl.head()
# Out:
#    id  season       city      date                        team1  \
# 0   1    2017  Hyderabad  5/4/2017          Sunrisers Hyderabad
# 1   2    2017       Pune  6/4/2017               Mumbai Indians
# 2   3    2017     Rajkot  7/4/2017                Gujarat Lions
# 3   4    2017     Indore  8/4/2017       Rising Pune Supergiant
# 4   5    2017  Bangalore  8/4/2017  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# 0  normal           0          Sunrisers Hyderabad           35
# ...

# %%
ipl.shape
# Out:
# (755, 18)

# %%
ipl.describe()
# Out:
#                  id       season  dl_applied  win_by_runs  win_by_wickets
# count    755.000000   755.000000  755.000000   755.000000      755.000000
# mean    1779.433113  2013.437086    0.025166    13.299338        3.354967
# std     3448.993305     3.363039    0.156732    23.482437        3.388009
# min        1.000000  2008.000000    0.000000     0.000000        0.000000
# 25%      189.500000  2011.000000    0.000000     0.000000        0.000000
# 50%      378.000000  2013.000000    0.000000     0.000000        4.000000
# 75%      566.500000  2016.000000    0.000000    19.000000        6.000000
# max    11414.000000  2019.000000    1.000000   146.000000       10.000000

# %%
ipl.isnull()
# Out:
#         id  season   city   date  team1  team2  toss_winner  toss_decision  \
# 0    False   False  False  False  False  False        False          False
# 1    False   False  False  False  False  False        False          False
# 2    False   False  False  False  False  False        False          False
# 3    False   False  False  False  False  False        False          False
# 4    False   False  False  False  False  False        False          False
# ..     ...     ...    ...    ...    ...    ...          ...            ...
# 750  False   False  False  False  False  False        False          False
# 751  False   False  False  False  False  False        False          False
# 752  False   False  False  False  False  False        False          False
# 753  False   False  False  False  False  False        False          False
# 754  False   False  False  False  False  False        False          False
#
# ...

# %%
ipl['player_of_match'].value_counts()
# Out:
# player_of_match
# CH Gayle          21
# AB de Villiers    20
# RG Sharma         17
# MS Dhoni          17
# DA Warner         17
#                   ..
# PD Collingwood     1
# NV Ojha            1
# AC Voges           1
# J Theron           1
# S Hetmyer          1
# Name: count, Length: 226, dtype: int64

# %%
ipl['player_of_match'].value_counts()[0:10]
# Out:
# player_of_match
# CH Gayle          21
# AB de Villiers    20
# RG Sharma         17
# MS Dhoni          17
# DA Warner         17
# YK Pathan         16
# SR Watson         15
# SK Raina          14
# G Gambhir         13
# MEK Hussey        12
# Name: count, dtype: int64

# %%
list(ipl['player_of_match'].value_counts().keys())
# Out:
# ['CH Gayle',
#  'AB de Villiers',
#  'RG Sharma',
#  'MS Dhoni',
#  'DA Warner',
#  'YK Pathan',
#  'SR Watson',
#  'SK Raina',
#  'G Gambhir',
#  'MEK Hussey',
#  'AM Rahane',
#  'V Kohli',
#  'V Sehwag',
#  'DR Smith',
#  'AD Russell',
#  'A Mishra',
#  'JH Kallis',
#  'KA Pollard',
#  'SE Marsh',
#  'AT Rayudu',
#  'SP Narine',
#  'Harbhajan Singh',
#  'SR Tendulkar',
#  'RA Jadeja',
#  'UT Yadav',
#  'Rashid Khan',
#  'RV Uthappa',
#  'AC Gilchrist',
#  'M Vijay',
#  'RR Pant',
#  'S Dhawan',
#  'SL Malinga',
#  'A Nehra',
#  'BJ Hodge',
#  'HH Pandya',
#  'SC Ganguly',
#  'SPD Smith',
#  'PA Patel',
#  'KC Sangakkara',
#  'DPMD Jayawardene',
#  'BB McCullum',
#  'JP Faulkner',
#  'AJ Finch',
#  'DW Steyn',
#  'Yuvraj Singh',
#  'SV Samson',
#  'GJ Maxwell',
#  'Sandeep Sharma',
#  'JD Unadkat',
#  'JC Buttler',
#  'B Kumar',
#  'NM Coulter-Nile',
#  'MK Pandey',
#  'JP Duminy',
#  'ML Hayden',
#  'SS Iyer',
#  'CA Lynn',
#  'KL Rahul',
#  'KH Pandya',
#  'KD Karthik',
# ...

# %%
plt.figure(figsize=(8,5))
plt.bar(ipl['player_of_match'].value_counts().index[0:10], ipl['player_of_match'].value_counts().values[0:10], color='red')
plt.xticks(rotation = 90)
plt.show()

# %%
ipl['toss_winner'].value_counts()
# Out:
# toss_winner
# Mumbai Indians                 97
# Kolkata Knight Riders          92
# Chennai Super Kings            89
# Royal Challengers Bangalore    81
# Kings XI Punjab                81
# Delhi Daredevils               80
# Rajasthan Royals               80
# Sunrisers Hyderabad            46
# Deccan Chargers                43
# Pune Warriors                  20
# Gujarat Lions                  15
# Delhi Capitals                 10
# Kochi Tuskers Kerala            8
# Rising Pune Supergiants         7
# Rising Pune Supergiant          6
# Name: count, dtype: int64

# %%
bat = ipl[ipl['toss_winner']!= 0]
bat.head()
# Out:
#    id  season       city      date                        team1  \
# 0   1    2017  Hyderabad  5/4/2017          Sunrisers Hyderabad
# 1   2    2017       Pune  6/4/2017               Mumbai Indians
# 2   3    2017     Rajkot  7/4/2017                Gujarat Lions
# 3   4    2017     Indore  8/4/2017       Rising Pune Supergiant
# 4   5    2017  Bangalore  8/4/2017  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# 0  normal           0          Sunrisers Hyderabad           35
# ...

# %%
bat2 = ipl[ipl['toss_decision']!= 'field']
bat2.head()
# Out:
#     id  season       city        date                        team1  \
# 4    5    2017  Bangalore    8/4/2017  Royal Challengers Bangalore
# 7    8    2017     Indore   10/4/2017  Royal Challengers Bangalore
# 14  15    2017      Delhi  15-04-2017             Delhi Daredevils
# 17  18    2017      Delhi  17-04-2017             Delhi Daredevils
# 20  21    2017  Hyderabad  19-04-2017          Sunrisers Hyderabad
#
#                     team2                  toss_winner toss_decision  result  \
# 4        Delhi Daredevils  Royal Challengers Bangalore           bat  normal
# 7         Kings XI Punjab  Royal Challengers Bangalore           bat  normal
# 14        Kings XI Punjab             Delhi Daredevils           bat  normal
# 17  Kolkata Knight Riders             Delhi Daredevils           bat  normal
# 20       Delhi Daredevils          Sunrisers Hyderabad           bat  normal
#
#     dl_applied                       winner  win_by_runs  win_by_wickets  \
# ...

# %%
plt.figure(figsize = (8,5))
plt.hist(bat['win_by_runs'])
plt.title('Distribution of runs')
plt.xlabel('Run')
plt.show()

# %%
bat['winner'].value_counts()
# Out:
# winner
# Mumbai Indians                 108
# Chennai Super Kings            100
# Kolkata Knight Riders           92
# Royal Challengers Bangalore     84
# Kings XI Punjab                 82
# Rajasthan Royals                75
# Delhi Daredevils                67
# Sunrisers Hyderabad             58
# Deccan Chargers                 29
# Gujarat Lions                   13
# Pune Warriors                   12
# Rising Pune Supergiant          10
# Delhi Capitals                  10
# Kochi Tuskers Kerala             6
# Rising Pune Supergiants          5
# Name: count, dtype: int64

# %%
plt.figure(figsize = (6,5))
plt.bar(ipl['winner'].value_counts().index[0:3], ipl['winner'].value_counts().values[0:3])
plt.title('Distribution of wins')
plt.xlabel('Teams')
plt.show()

# %%
plt.pie(ipl['winner'].value_counts().values[0:3], labels=ipl['winner'].value_counts().index[0:3])
plt.show()
